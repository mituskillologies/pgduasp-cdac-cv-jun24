# %% [markdown]
# ##### Image Shift / Translation

# %%
import cv2 
import numpy as np 
  
image = cv2.imread('lenna.png') 
  
# Store height and width of the image 
height, width = image.shape[:2] 
  
quarter_height, quarter_width = height / 4, width / 4
  
T = np.float32([[1, 0, quarter_width], [0, 1, quarter_height]]) 
  
# We use warpAffine to transform the image using the matrix, T 
img_translation = cv2.warpAffine(image, T, (width, height)) 
  
cv2.imshow("Originalimage", image) 
cv2.imshow('Translation', img_translation) 
cv2.waitKey() 
  
cv2.destroyAllWindows()

# %%
T
# Out:
# array([[  1.,   0., 128.],
#        [  0.,   1., 128.]], dtype=float32)

# %%
import cv2 
import numpy as np 
  
image = cv2.imread('lenna.png') 
  
T = np.float32([[1, 0, 50], [0, 1, 0]]) 
  
# We use warpAffine to transform the image using the matrix, T 
img_translation = cv2.warpAffine(image, T, (width, height)) 
  
cv2.imshow("Originalimage", image) 
cv2.imshow('Translation', img_translation) 
cv2.waitKey() 
  
cv2.destroyAllWindows()

# %%
# Out:
# array([[ 1.,  0., 50.],
#        [ 0.,  1.,  0.]], dtype=float32)

# %%
# opposite translation

import cv2 
import numpy as np 
  
image = cv2.imread('lenna.png') 
  
T = np.float32([[1, 0, -50], [0, 1, -20]]) 
  
# We use warpAffine to transform the image using the matrix, T 
img_translation = cv2.warpAffine(image, T, (width, height)) 
  
cv2.imshow("Originalimage", image) 
cv2.imshow('Translation', img_translation) 
cv2.waitKey() 
  
cv2.destroyAllWindows()

# %%
import cv2 
import numpy as np 
  
image = cv2.imread('lenna.png') 
  
T = np.float32([[1, 0, 50], [0, 1, 20]]) 
  
# We use warpAffine to transform the image using the matrix, T 
img_translation1 = cv2.warpAffine(img_translation, T, (width, height)) 
  
cv2.imshow("Originalimage", img_translation) 
cv2.imshow('Translation', img_translation1) 
cv2.waitKey() 
  
cv2.destroyAllWindows()

# %%
x = np.arange(1,25,0.25)

# %%
y = np.sin(x)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y, color = 'r')
plt.plot(x, np.cos(y), color = 'b')

# %% [markdown]
# ##### Image Rotation
