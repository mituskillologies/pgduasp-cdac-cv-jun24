# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Load an image
image = cv2.imread('lenna.png')

# Define starting and ending points of the line
start_point = (100, 50)  # (x1, y1)
end_point = (300, 200)   # (x2, y2)

# Draw a green line with thickness of 2 pixels
cv2.line(image, start_point, end_point, (0, 255, 0), 2)

# Display the image with the line
cv2.imshow('Image with Line', image)
cv2.waitKey(0)o
cv2.destroyAllWindows()

# %%
# Load an image
image = cv2.imread('lenna.png')

# Define starting and ending points of the line
start_point = (100, 50)  # (x1, y1)
end_point = (300, 200)   # (x2, y2)

# Draw a green line with thickness of 2 pixels
#cv2.line(image, start_point, end_point, (0, 255, 0), 2)
cv2.line(image, (0,0), (511,511), (163, 189, 111), 2)
cv2.line(image, (511,0), (0,511), (0, 255, 255), 5)

# Display the image with the line
cv2.imshow('Image with Line', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Line using equation

# %%
import numpy as np

# %%
num = np.arange(10,20,0.5)

# %%
y = num * 17.5 + 3.1

# %%
plt.xlim(10, 20)
plt.ylim(0, max(y)+1)
plt.plot(num, y)
plt.scatter(num, y, color = 'orange')

# %% [markdown]
# ##### 3D Line Drawing

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# Define start and end points of the line in 3D space
start_point = (10, 22, 33)
end_point = (44, 52, 67)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the line
ax.plot([start_point[0], end_point[0]],
        [start_point[1], end_point[1]],
        [start_point[2], end_point[2]], 'r-')

ax.plot([10, 40],[55, 35],[35, 30],'g')

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Line')

# Show the plot
plt.show()

# %%
import turtle

# Create a turtle object
t = turtle.Turtle()

# Set the line width (optional)
t.pensize(3)

# Move the turtle to the starting position
t.penup()
t.goto(0, -50)  # Replace with your desired starting coordinates (x, y)
t.pendown()

# Move the turtle to the ending position (drawing the line)
t.goto(300, 0)  # Replace with your desired ending coordinates (x, y)

# Keep the window open until closed manually
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[3], line 7
#       4 t = turtle.Turtle()
#       6 # Set the line width (optional)
# ----> 7 t.pensize(3)
#       9 # Move the turtle to the starting position
#      10 t.penup()
#
# File /usr/lib/python3.10/turtle.py:2092, in TPen.pensize(self, width)
#    2090 if width is None:
#    2091     return self._pensize
# -> 2092 self.pen(pensize=width)
#
# File /usr/lib/python3.10/turtle.py:2425, in TPen.pen(self, pen, **pendict)
#    2423         newLine = True
#    2424 if newLine:
# -> 2425     self._newLine()
#    2426 if "pendown" in p:
#    2427     self._drawing = p["pendown"]
#
# File /usr/lib/python3.10/turtle.py:3292, in RawTurtle._newLine(self, usePos)
#    3290     self.items.append(self.currentLineItem)
#    3291 else:
# -> 3292     self.screen._drawline(self.currentLineItem, top=True)
#    3293 self.currentLine = []
#    3294 if usePos:
#
# File /usr/lib/python3.10/turtle.py:550, in TurtleScreenBase._drawline(self, lineitem, coordlist, fill, width, top)
#     548     self.cv.itemconfigure(lineitem, width=width)
#     549 if top:
# --> 550     self.cv.tag_raise(lineitem)
#
# File <string>:1, in tag_raise(self, *args, **kw)
#
# File /usr/lib/python3.10/tkinter/__init__.py:2971, in Canvas.tag_raise(self, *args)
#    2968 def tag_raise(self, *args):
#    2969     """Raise an item TAGORID given in ARGS
#    2970     (optional above another item)."""
# -> 2971     self.tk.call((self._w, 'raise') + args)
#
# TclError: invalid command name ".!canvas"

# %% [markdown]
# ##### Rectangles

# %%
import cv2

# Load your image
image = cv2.imread("lenna.png")

# Define top-left corner and dimensions
x, y, w, h = 100, 50, 200, 150

# Draw a blue rectangle with thickness of 2 pixels
cv2.rectangle(image, (x, y), (x + w, y + h), (255, 0, 0), 10)

# Show the image with the rectangle
cv2.imshow("Image with Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.

# %%
import cv2

# Load your image
image = cv2.imread("lenna.png")

# Define top-left corner and dimensions
x, y, w, h = 100, 50, 200, 150

# Draw a blue rectangle with thickness of 2 pixels
cv2.rectangle(image, (0, 0), (255,255), (255, 255, 0), 10)
cv2.rectangle(image, (255, 0), (512,255), (127, 255, 0), 10)
cv2.rectangle(image, (0, 255), (255,512), (127, 255, 255), 10)
cv2.rectangle(image, (255, 255), (512,512), (0, 0, 255), 10)

# Show the image with the rectangle
cv2.imshow("Image with Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np

image = np.ones([200,300]) - 0.25
cv2.rectangle(image, (50, 50), (250, 150), (0, 140, 0), 10)
cv2.imshow('Sample Image', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Rectangle using matplotlib

# %%
import matplotlib.pyplot as plt

# Define rectangle coordinates
x_min, y_min, x_max, y_max = 1, 2, 4, 7

# Create the rectangle patch
rectangle = plt.Rectangle((x_min, y_min), x_max - x_min, y_max - y_min,
                         color='red', alpha=0.4)

# Add the rectangle to a plot and customize labels/title
plt.plot([x_min, x_max], [y_min, y_min], 'b-', label='X-axis')
plt.plot([x_min, x_min], [y_min, y_max], 'g-', label='Y-axis')
plt.gca().add_patch(rectangle)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Rectangle Plot")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ##### Rectangle using turtle

# %%
import turtle

# Create a Turtle object
t = turtle.Turtle()
# Set color and pen size
t.color("green")
t.pensize(5)
t.speed(0)
# Move the Turtle and draw the rectangle
t.penup()
t.goto(-50, 25)
t.pendown()
t.forward(100)
t.left(90)
t.forward(50)
t.left(90)
t.forward(100)
t.left(90)
t.forward(50)
t.hideturtle()

# Start the Turtle graphics window
turtle.done()

# %% [markdown]
# ##### Drawing Ellipse

# %%
import cv2

# Load an image
image = cv2.imread("lenna.png")

# Define center coordinates, radii, and angle
center = (150, 100)  # (x, y)
axes = (100, 50)  # (major_radius, minor_radius)
angle = 45  # Angle of rotation in degrees

# Draw a green ellipse with thickness of 3 pixels
cv2.ellipse(image, center, axes, angle, 0, 360, (0, 255, 0), 3)
cv2.ellipse(image, (200,400), axes, 0, 0, 360, (0, 255, 0), 3)

# Display the image with the ellipse
cv2.imshow("Image with Ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load an image
image = cv2.imread("lenna.png")

# Define center coordinates, radii, and angle
center = (255, 255)  # (x, y)
axes = (150, 255)  # (major_radius, minor_radius)
angle = 0  # Angle of rotation in degrees

# Draw a green ellipse with thickness of 3 pixels
cv2.ellipse(image, center, axes, angle, 0, 360, (0, 255, 0), 5)

# Display the image with the ellipse
cv2.imshow("Image with Ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
# Load an image
image = cv2.imread("lenna.png")

# Define center coordinates, radii, and angle
center = (255, 255)  # (x, y)
axes = (150, 255)  # (major_radius, minor_radius)
angle = 0  # Angle of rotation in degrees

# Draw a green ellipse with thickness of 3 pixels
cv2.ellipse(image, center, axes, angle, 180, 360, (255, 0, 0), 5)
cv2.ellipse(image, center, axes, angle, 0, 180, (0, 0, 255), 5)

# Display the image with the ellipse
cv2.imshow("Image with Ellipse", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.

# %% [markdown]
# ##### Ellipse using matplotlib

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# Define center coordinates, radii, and angle
center = (0, 0)
width = 8
height = 5
angle = 45

# Create the ellipse object
ellipse = Ellipse(xy=center, width=width, height=height, angle=angle, color='blue')

# Add the ellipse to the plot
fig, ax = plt.subplots()
ax.add_patch(ellipse)
ax.set_aspect('equal')  # Maintain equal aspect ratio for correct shape

# Set limits slightly wider than the ellipse
ax.set_xlim(-width - width/5, width + width/5)
ax.set_ylim(-height - height/5, height + height/5)

# Add labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Ellipse Plot')

# Show the plot
plt.show()

# %% [markdown]
# ##### Drawing circle

# %%
import cv2

# Load an image
image = cv2.imread("lenna.png")

# Define center coordinates and radius
center = (100, 100)  # (x, y)
radius = 50

# Draw a red circle with thickness of 4 pixels
cv2.circle(image, center, radius, (0, 0, 255), 4)

# Display the image with the circle
cv2.imshow("Image with Circle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Load an image
image = cv2.imread("lenna.png")

# Define center coordinates and radius
center = (255, 255)  # (x, y)

# Draw a red circle with thickness of 4 pixels
for i in range(10,401,5):
    cv2.circle(image, center, i, (0, i//2, i), 2)

# Display the image with the circle
cv2.imshow("Image with Circle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Circles using matplotlib

# %%
import matplotlib.pyplot as plt

# Define center coordinates and radius
center = (0, 0)
radius = 3

# Create the circle object
circle = plt.Circle(xy=center, radius=radius, color='orange')

# Add the circle to the plot
fig, ax = plt.subplots()
ax.add_patch(circle)
ax.set_aspect('equal')  # Maintain equal aspect ratio for correct shape

# Set limits slightly wider than the circle
ax.set_xlim(-radius - radius/5, radius + radius/5)
ax.set_ylim(-radius - radius/5, radius + radius/5)

# Add labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Circle Plot')

# Show the plot
plt.show()

# %% [markdown]
# ##### Using Tkinter library

# %%
from tkinter import *

# %%
top = Tk()

top.mainloop()

# %%
top = Tk()
top.geometry('800x500')
top.title('My Window')

Label(top, text='Enter your name:').pack()
Entry(top).pack()
Button(top, text='Submit').pack()
top.mainloop()

# %%
top = Tk()
top.geometry('800x500')
top.title('My Window')

Label(top, text='Enter your name:').place(x=50,y=50)
Entry(top).place(x=50,y=80)
Button(top, text='Submit').place(x=50,y=110)
top.mainloop()

# %%
# Event Handling

top = Tk()
top.geometry('800x500')
top.title('My Window')

def show():
    Label(top, text="Your name: "+str(e.get()).upper()).place(x=50,y=150)

Label(top, text='Enter your name:').place(x=50,y=50)
e = Entry(top)
e.place(x=50,y=80)
Button(top, text='Submit', command = show).place(x=50,y=110)
top.mainloop()

# %%
# Create the main window
root = Tk()
root.title("Drawing Canvas")
root.geometry('1000x800')

# Create the canvas widget
canvas = Canvas(root, width=1000, height=800, bg="white")
canvas.pack()

# Define drawing functions
def draw_line(event):
    x1, y1 = event.x, event.y
    canvas.create_line(x1, y1, x1+2, y1+2, width=2)
    
def draw_circle(event):
    x1, y1 = event.x, event.y
    canvas.create_oval(x1 - 5, y1 - 5, x1 + 5, y1 + 5, fill="yellow")

# Bind mouse events to drawing functions
canvas.bind("<Button-3>", draw_circle)
canvas.bind("<B1-Motion>", draw_line)

# Start the main loop
root.mainloop()

# %% [markdown]
# ##### Mouse Operations

# %%
import cv2

# Load an image
img = cv2.imread("lenna.png")

# Define the callback function
def draw_circle(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        cv2.circle(img, (x, y), 10, (0, 255, 0), -1)  # Draw a green circle

# Bind the callback function
cv2.namedWindow("image")
cv2.setMouseCallback("image", draw_circle)

# Show the image and wait for events
while True:
    cv2.imshow("image", img)
    if cv2.waitKey(1) == ord("q"):
        break

cv2.destroyAllWindows()

# %% [markdown]
# ##### Image Annotation

# %%
import cv2

# Define text and rectangle properties
text = "Sample Text"
font_face = cv2.FONT_HERSHEY_COMPLEX
font_scale = 1.0
color = (0, 255, 145)  # Green
thickness = 2

# Calculate text width and height
text_size, baseline = cv2.getTextSize(text, font_face, font_scale, thickness)

# Define text and rectangle positions
text_origin = (200, 200)
box_origin = (text_origin[0] - 10, text_origin[1] - baseline - 20)
box_width, box_height = text_size[0] + 20, text_size[1] + 20

image = cv2.imread("lenna.png")

# Draw the rectangle and text
cv2.rectangle(image, box_origin, (box_origin[0] + box_width, 
                                  box_origin[1] + box_height), color, thickness)
cv2.putText(image, text, text_origin, font_face, font_scale, color, thickness)

# Display the annotated image
cv2.imshow("Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Annotation using matplotlib

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [2, 5, 1]

plt.plot(x, y)
plt.text(2, 4, "Data Point", fontsize=14, color="red")  # Annotate a specific point
plt.title("Example Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
plt.plot(x, y)
plt.annotate("Peak value", (2, 5), xytext=(1.5, 5.5), 
             arrowprops=dict(edgecolor='red', facecolor='green'))
plt.annotate("Start value", (1, 2), xytext=(1.25, 1.5), 
             arrowprops=dict(edgecolor='magenta', facecolor='yellow'))
plt.annotate("End value", (3, 1), xytext=(2.5, 1.1), 
             arrowprops=dict(edgecolor='black', facecolor='blue'))
plt.show()
